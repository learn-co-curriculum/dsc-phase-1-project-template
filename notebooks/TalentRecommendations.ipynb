# %% [markdown]
# # Data Analysis on Directors, Producers, Actors, Actresses, Writers
#
# ## The goal of this data analysis is to suggest people to staff for the movie in regards their success. Success is measured using ROI. We reviewed directors, actors, actresses, producers, and writers. This dataset is from 2010-2020.
#
# First we locate the dataframe we want to reference separating them by role. This notebook is broken down by each role, using the same code in each to find suitable candidates to suggest.

# %%
## Import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import sqlite3

#This is to query the data set below. This is not necesary with learn-env, but is with ipykernel
#! pip install -U pandasql

from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
# Out:
# Requirement already satisfied: pandasql in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (0.7.3)
# Requirement already satisfied: numpy in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (1.21.5)
# Requirement already satisfied: pandas in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (1.4.4)
# Requirement already satisfied: sqlalchemy in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (1.4.39)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from pandas->pandasql) (2022.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy->pandasql) (1.1.1)
# Requirement already satisfied: six>=1.5 in /Users/RachaelMcCue/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)

# %%
# References the master dataset in the notebook. Drops the records where gross=0, since this is likely an error in the data.

master_df = pd.read_pickle('movie_master_dataset_with_inflation.pkl')
master_df = master_df[master_df['worldwide_gross'] != 0]

# %%
##data is from 2010-2020
master_df['release_date'].dt.year.value_counts()
# Out:
# 2011    1729
# 2014    1648
# 2010    1645
# 2015    1605
# 2013    1585
# 2016    1532
# 2012    1476
# 2017    1181
# 2018    1179
# 2019     330
# Name: release_date, dtype: int64

# %%
master_df.head()
# Out:
#   release_date                                        movie  \
# 0   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 4   2011-05-20  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  inf_adj_production_budget  domestic_gross  \
# 0          410600000                  539310899       241063875
# 1          410600000                  539310899       241063875
# 2          410600000                  539310899       241063875
# 3          410600000                  539310899       241063875
# 4          410600000                  539310899       241063875
#
#    worldwide_gross  worldwide_profit       ROI     person_name movie_role  \
# 0       1045663875         635063875  1.546673     Johnny Depp      actor
# 1       1045663875         635063875  1.546673   Geoffrey Rush      actor
# 2       1045663875         635063875  1.546673   Penélope Cruz    actress
# 3       1045663875         635063875  1.546673  Stuart Beattie     writer
# 4       1045663875         635063875  1.546673     Ted Elliott     writer
#
#    ...   News  Reality-TV  Romance  Sci-Fi  Short  Sport  Talk-Show  Thriller  \
# 0  ...  False       False    False   False  False  False      False     False
# 1  ...  False       False    False   False  False  False      False     False
# 2  ...  False       False    False   False  False  False      False     False
# 3  ...  False       False    False   False  False  False      False     False
# 4  ...  False       False    False   False  False  False      False     False
#
#      War  Western
# 0  False    False
# 1  False    False
# 2  False    False
# 3  False    False
# 4  False    False
#
# [5 rows x 37 columns]

# %%
master_df['movie_role'].value_counts().head() ##types of roles. There are almost twice as many actors as actresses
# Out:
# actor       3486
# producer    2747
# writer      2663
# actress     2028
# director    1502
# Name: movie_role, dtype: int64

# %% [markdown]
# <b>The cell below gets the stats for movies with a budget over 10 million - to rule out independent and smaller films.
# We will reference the median, as it is robust to outliers.</b>

# %%
master_df[master_df['inf_adj_production_budget'] > 1e7]['inf_adj_production_budget'].describe()
# Out:
# count    1.112700e+04
# mean     7.473626e+07
# std      7.376893e+07
# min      1.003858e+07
# 25%      2.458659e+07
# 50%      4.510984e+07
# 75%      9.983165e+07
# max      5.393109e+08
# Name: inf_adj_production_budget, dtype: float64

# %% [markdown]
# <b>Takeaway:
#    The budget 25% percentile is 2.4 million
#    The median is 4.5 million
#    The 75% is 9.9 million

# %% [markdown]
# <b>Establish new dateframes that orangize by role. Directors, Actors, Actresses, Producers, Writers.</b>

# %%
directors = master_df[master_df['movie_role'] == "director"] ##dataframe of directors only

# %%
actors = master_df.loc[master_df['movie_role'] == "actor"] ##dataframe of actors only

# %%
actresses = master_df.loc[master_df['movie_role'] == "actress"] ##dataframe of actresses only

# %%
producers = master_df[master_df['movie_role'] == "producer"]##dataframe of producers only

# %%
writers = master_df[master_df['movie_role'] == "writer"] ##dataframe of writers only

# %% [markdown]
# ## DIRECTORS
#
# ### This section outlines director recommendations. We use a sequence of queries, and loops to narrow the directors that were a part of movies using a 24mil+ budget, and directed at least 3 movies since 2010.

# %%
## The following cell queries the directors dataframe with a $30Mill+ budget.

dq1 = ("""
SELECT person_name, movie, inf_adj_production_budget, ROI, Comedy, Adventure, Action
FROM directors
WHERE inf_adj_production_budget >= 2.4e7
ORDER BY ROI
""")

directors_q1 = pysqldf(dq1) 
directors_q1
# Out:
#            person_name              movie  inf_adj_production_budget  \
# 0    Lawrence Kasanoff         Foodfight!                   58169890
# 1     Robbie Pickering   Freaks of Nature                   41180555
# 2     David O. Russell    Accidental Love                   32681495
# 3      Taylor Hackford         Love Ranch                   34041818
# 4            Xiao Feng         Air Strike                   76286869
# ..                 ...                ...                        ...
# 906         Kyle Balda            Minions                   92028535
# 907          James Wan      The Conjuring                   25411137
# 908       Bryan Singer  Bohemian Rhapsody                   64767356
# 909    Andy Muschietti                 It                   42087096
# 910    Damien Chazelle         La La Land                   24586384
#
#            ROI  Comedy  Adventure  Action
# 0    -0.998362       1          0       1
# 1    -0.997850       1          0       0
# 2    -0.994791       1          0       0
# 3    -0.994154       1          0       0
# 4    -0.992057       0          1       1
# ..         ...     ...        ...     ...
# 906  14.680219       1          1       0
# 907  14.900007       0          0       0
# 908  15.272461       0          0       0
# 909  18.927371       0          0       0
# 910  20.317558       1          0       0
#
# [911 rows x 7 columns]

# %%
#This loop sorts by number of movies, and selects the ones that have made 3 or more

three_movies_dq1 = []
for x, y in zip(directors_q1['person_name'].value_counts(), directors_q1['person_name'].value_counts().index.tolist()):
    if x >= 3:
        three_movies_dq1.append(y)
    
three_movies_dq1
# Out:
# ['Steven Spielberg',
#  'Clint Eastwood',
#  'Ridley Scott',
#  'Zack Snyder',
#  'Peter Berg',
#  'Ron Howard',
#  'Francis Lawrence',
#  'Antoine Fuqua',
#  'Baltasar Kormákur',
#  'Paul W.S. Anderson',
#  'Jaume Collet-Serra',
#  'Brad Peyton',
#  'Peter Farrelly',
#  'Lasse Hallström',
#  'Adam McKay',
#  'Martin Scorsese',
#  'Joe Wright',
#  'Mike Mitchell',
#  'Robert Zemeckis',
#  'Michael Bay',
#  'Jonathan Levine',
#  'Bryan Singer',
#  'Christopher Nolan',
#  'Simon West',
#  'Tim Burton',
#  'Denis Villeneuve',
#  'Chris Renaud',
#  'David O. Russell',
#  'Nicholas Stoller',
#  'Shawn Levy',
#  'Tim Story',
#  'Jon M. Chu',
#  'David Yates',
#  'Joe Johnston',
#  'Phil Lord',
#  'David Ayer',
#  'Joe Russo',
#  'Roland Emmerich',
#  'Guy Ritchie',
#  'Robert Rodriguez',
#  'Dennis Dugan',
#  'Craig Gillespie',
#  'Louis Leterrier',
#  'Genndy Tartakovsky',
#  'Malcolm D. Lee',
#  'Paul Greengrass',
#  'Seth Gordon',
#  'Sean Anders',
#  'Peter Jackson',
#  'Don Hall',
#  'Andy Fickman',
#  'Dean DeBlois',
#  'Paul Feig',
#  'Jake Kasdan',
#  'Steven Soderbergh',
#  'George Tillman Jr.',
#  'Ruben Fleischer',
#  'James Bobin',
#  'Todd Phillips',
#  'Matt Reeves',
#  'Frank Coraci',
#  'Jon Turteltaub',
#  'Bobby Farrelly',
#  'Luc Besson',
#  'Shane Black',
#  'Jennifer Yuh Nelson',
#  'Tate Taylor',
#  'Martin Campbell',
#  'Christopher Miller',
#  'Anthony Russo',
#  'David Frankel',
#  'F. Gary Gray',
#  'James Wan',
#  'David Fincher',
#  'Pierre Coffin',
#  'Daniel Espinosa',
#  'Brad Furman',
#  'David Leitch',
#  'Marc Forster',
#  'James Mangold',
#  'Rupert Wyatt',
#  'Tom McGrath',
#  'Rob Marshall',
#  'Carlos Saldanha',
#  'David Gordon Green',
#  'Will Gluck',
#  'Matthew Vaughn',
#  'Rawson Marshall Thurber']

# %% [markdown]
# <b>Get the ROI of all the directors and get the mean of those ROIs for each individual. Then they must be involved in Action, Adventure, and Comedy.</b>

# %%
# This gets two lists, one is the names of directors, the other is the respective ROIs. 
# This loop also sorts by genres Action, Adventure, Comedy.

names_df1 = []
ROI_df1 = []
for x in three_movies_dq1:
    ROI_df1_mean = directors_q1[directors_q1['person_name'] == x]['ROI'].mean()
    this_actor = directors_q1[directors_q1['person_name'] == x]
    if this_actor['Action'].sum() + this_actor['Adventure'].sum() + this_actor['Comedy'].sum() > 0:
        names_df1.append(x)
        ROI_df1.append(ROI_df1_mean)

#This zips the above loops and puts them into a dataframe. The dataframe will be used for visualization.
    
zipped_name_ROI_df1 = sorted(zip(names_df1, ROI_df1), reverse=True)
df1 = pd.DataFrame(zipped_name_ROI_df1, columns=['Director Names', 'Average ROI'])
df1.sort_values(by='Average ROI', ascending=False, inplace=True)
df1
# Out:
#         Director Names  Average ROI
# 22       Pierre Coffin    10.501490
# 50           James Wan     9.353792
# 75        Chris Renaud     7.487083
# 53         Jake Kasdan     7.402594
# 23           Phil Lord     5.361456
# ..                 ...          ...
# 16     Roland Emmerich     0.424337
# 8           Simon West     0.393356
# 18    Robert Rodriguez     0.303165
# 71     Craig Gillespie     0.207672
# 67  David Gordon Green    -0.211566
#
# [85 rows x 2 columns]

# %% [markdown]
# <b>Plot the figures to show directors and their respective avergage ROI.</b>

# %%
sns.barplot(data=df1.head(12), x='Director Names', y="Average ROI")
 
# Rotate x-labels
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# # ACTORS
#
# ### This section outlines actor recommendations. We use a sequence of queries, and loops to narrow the actors that were a part of movies using a 24mil+ budget, and were casted in at least 3 movies since 2010.¶

# %%
## This cell queries the actors dataframe with a $24Mill+ budget.

aq1 = ("""
SELECT person_name, movie, inf_adj_production_budget, ROI, Comedy, Adventure, Action
FROM actors
WHERE inf_adj_production_budget >= 2.4e7
ORDER BY ROI
""")

actors_q1 = pysqldf(aq1)

# %%
actors_q1
# Out:
#                person_name             movie  inf_adj_production_budget  \
# 0            Charlie Sheen        Foodfight!                   58169890
# 1              Denis Leary  Freaks of Nature                   41180555
# 2           Nicholas Braun  Freaks of Nature                   41180555
# 3               Josh Fadem  Freaks of Nature                   41180555
# 4     Raymond L. Brown Jr.   Accidental Love                   32681495
# ...                    ...               ...                        ...
# 2243        Bill Skarsgård                It                   42087096
# 2244        Jaeden Martell                It                   42087096
# 2245         Finn Wolfhard                It                   42087096
# 2246          Ryan Gosling        La La Land                   24586384
# 2247          J.K. Simmons        La La Land                   24586384
#
#             ROI  Comedy  Adventure  Action
# 0     -0.998362       1          0       1
# 1     -0.997850       1          0       0
# 2     -0.997850       1          0       0
# 3     -0.997850       1          0       0
# 4     -0.994791       1          0       0
# ...         ...     ...        ...     ...
# 2243  18.927371       0          0       0
# 2244  18.927371       0          0       0
# 2245  18.927371       0          0       0
# 2246  20.317558       1          0       0
# 2247  20.317558       1          0       0
#
# [2248 rows x 7 columns]

# %%
#This loop sorts by number of movies, and selects the actors that have been casted 3 or more

three_movies_aq1 = []
for x, y in zip(actors_q1['person_name'].value_counts(), actors_q1['person_name'].value_counts().index.tolist()):
    if x >= 3:
        three_movies_aq1.append(y)
    
three_movies_aq1
# Out:
# ['Mark Wahlberg',
#  'Dwayne Johnson',
#  'Liam Neeson',
#  'Owen Wilson',
#  'Steve Carell',
#  'Johnny Depp',
#  'Jason Statham',
#  'Channing Tatum',
#  'Chris Hemsworth',
#  'Michael Fassbender',
#  'Robert De Niro',
#  'Tom Hardy',
#  'Gary Oldman',
#  'Kevin Hart',
#  'Matt Damon',
#  'Kevin James',
#  'Morgan Freeman',
#  'Tom Hanks',
#  'Josh Brolin',
#  'Robert Downey Jr.',
#  'Denzel Washington',
#  'Ryan Reynolds',
#  'Bradley Cooper',
#  'Gerard Butler',
#  'Brad Pitt',
#  'Jonah Hill',
#  'Chris Pratt',
#  'Will Ferrell',
#  'Matthew McConaughey',
#  'Jesse Eisenberg',
#  'Chris Pine',
#  'Adam Sandler',
#  'Hugh Jackman',
#  'Nicolas Cage',
#  'Chris Evans',
#  'James McAvoy',
#  'Seth Rogen',
#  'Ben Affleck',
#  'Christoph Waltz',
#  'Justin Timberlake',
#  'John Goodman',
#  'George Clooney',
#  'Harrison Ford',
#  'Liam Hemsworth',
#  'Tom Cruise',
#  'Ralph Fiennes',
#  'Joel Edgerton',
#  'Woody Harrelson',
#  'Ryan Gosling',
#  'Joseph Gordon-Levitt',
#  'Jason Bateman',
#  'Mark Strong',
#  'Ben Stiller',
#  'Mark Ruffalo',
#  'Jamie Foxx',
#  'James Franco',
#  'Colin Farrell',
#  'Jake Gyllenhaal',
#  'Samuel L. Jackson',
#  'Idris Elba',
#  'Sylvester Stallone',
#  'Bruce Willis',
#  'Leonardo DiCaprio',
#  'Vin Diesel',
#  'Josh Hutcherson',
#  'Jude Law',
#  'Will Smith',
#  'Daniel Craig',
#  'Jeremy Renner',
#  'Russell Crowe',
#  'Anthony Mackie',
#  'Jason Clarke',
#  'Andy Samberg',
#  'John C. Reilly',
#  'Aaron Eckhart',
#  'Martin Freeman',
#  'Anthony Hopkins',
#  'Ice Cube',
#  'Will Arnett',
#  'Dominic Cooper',
#  'Christian Bale',
#  'Ed Helms',
#  'Jon Hamm',
#  'John Leguizamo',
#  'Jason Sudeikis',
#  'Tom Hiddleston',
#  'Jack Black',
#  'Zac Efron',
#  'Aaron Taylor-Johnson',
#  'Ben Kingsley',
#  'Jason Segel',
#  'Michael Keaton',
#  'Tyler Perry',
#  'Jay Baruchel',
#  'John Malkovich',
#  'Neil Patrick Harris',
#  'Russell Brand',
#  "Vincent D'Onofrio",
#  'Logan Lerman',
#  'Forest Whitaker',
#  'Kevin Costner',
#  'Vince Vaughn',
#  'James Marsden',
#  'Chadwick Boseman',
#  'Javier Bardem',
#  'Jeff Bridges',
#  'Paul Rudd',
#  'Michael Shannon',
#  'Nicholas Hoult',
#  'Chiwetel Ejiofor',
#  'Ewan McGregor',
#  'Jackie Chan',
#  'Tommy Lee Jones',
#  'Ben Foster',
#  'Dan Fogler',
#  'Benedict Cumberbatch',
#  'Rodrigo Santoro',
#  'Sam Worthington',
#  'Antonio Banderas',
#  'T.J. Miller',
#  'Alec Baldwin',
#  'Ben Mendelsohn',
#  'Zach Galifianakis',
#  'Andy Serkis',
#  'Bryan Cranston',
#  'Andrew Garfield',
#  'Charlie Day',
#  'Jamie Bell',
#  'Jon Bernthal',
#  'Michael Peña',
#  'Kodi Smit-McPhee',
#  'Ron Perlman',
#  'Richard Jenkins',
#  'Miles Teller',
#  'Sharlto Copley',
#  'Philip Seymour Hoffman',
#  'Michael B. Jordan',
#  'Danny McBride',
#  'Josh Gad',
#  'Ian McKellen',
#  'Casey Affleck',
#  'Zachary Quinto',
#  'Geoffrey Rush',
#  'Alan Arkin',
#  'Hugo Weaving',
#  'Josh Duhamel',
#  'John Cusack',
#  'Christopher Mintz-Plasse',
#  'Taylor Kitsch',
#  'Henry Cavill',
#  'Kyle Chandler',
#  'Karl Urban',
#  'Domhnall Gleeson',
#  'Willem Dafoe',
#  'Richard Armitage',
#  'Taron Egerton',
#  'Brendan Gleeson',
#  'Dennis Quaid',
#  'Edgar Ramírez',
#  'Eddie Redmayne',
#  'Mel Gibson',
#  'Paul Giamatti',
#  'Chris Rock',
#  'Patrick Wilson',
#  'Benicio Del Toro',
#  'Sean Penn',
#  'Dave Franco',
#  'Don Cheadle',
#  'Jack Huston',
#  'Jemaine Clement',
#  'Mark Rylance',
#  'Steve Buscemi',
#  "Dylan O'Brien",
#  'Simon Pegg',
#  'Jared Harris',
#  'Mickey Rourke',
#  "O'Shea Jackson Jr.",
#  'Cillian Murphy',
#  'Paul Bettany',
#  'Hugh Grant',
#  'Luke Evans',
#  'Justin Long',
#  'Jeffrey Wright',
#  'Luke Bracey',
#  'Colin Firth',
#  'Stanley Tucci',
#  'Bill Nighy',
#  'Greg Kinnear',
#  'Alden Ehrenreich',
#  'J.K. Simmons',
#  'Jack McBrayer',
#  'Charlie Hunnam',
#  'Walton Goggins',
#  'Ian McShane',
#  'David Harbour',
#  'Alfred Molina',
#  'Armie Hammer',
#  'Jason Momoa',
#  'William Fichtner',
#  'Bill Hader',
#  'Sam Rockwell',
#  'Eric Bana',
#  'John Cena',
#  'Dominic West',
#  'Craig Ferguson',
#  'Joel Kinnaman',
#  'Edward Norton',
#  'Jamie Dornan',
#  'Seth MacFarlane',
#  'Mahershala Ali',
#  'Alexander Skarsgård',
#  'Danny Huston',
#  'Denis Leary',
#  'Sam Claflin',
#  'Benjamin Bratt',
#  'Daniel Brühl',
#  'Guy Pearce',
#  'Ray Stevenson',
#  'Joaquin Phoenix',
#  'Ben Whishaw',
#  'Boyd Holbrook',
#  'Jack Reynor',
#  'Jeff Goldblum',
#  "Jack O'Connell",
#  'Irrfan Khan',
#  'Ken Watanabe',
#  'Michael Caine',
#  'Alan Alda',
#  'Jordi Mollà',
#  'Shia LaBeouf',
#  'Giovanni Ribisi',
#  'Scott Eastwood',
#  'Eddie Murphy',
#  'James Corden',
#  'Brandon T. Jackson',
#  'Asa Butterfield',
#  'Liev Schreiber',
#  'David Thewlis',
#  'Benedict Wong',
#  'Arnold Schwarzenegger',
#  'Matthew Macfadyen',
#  'Cliff Curtis',
#  'Brendan Fraser',
#  'Pierce Brosnan',
#  'Nick Frost',
#  'Diego Luna',
#  'Billy Bob Thornton',
#  'Will Poulter',
#  'Paul Walker']

# %% [markdown]
# <b>Get the ROI of all the actors and get the mean of those ROIs for each individual. Then they must be involved in Action, Adventure, and Comedy.</b>

# %%
# This gets two lists, one is the names of actors, the other is the respective ROIs. 
# This loop also sorts by genres Action, Adventure, Comedy.


names_aq1 = []
ROI_aq1 = []
for x in three_movies_aq1:
    ROI_aq1_mean = actors_q1[actors_q1['person_name'] == x]['ROI'].mean()
    this_actor = actors_q1[actors_q1['person_name'] == x]
    if this_actor['Action'].sum() + this_actor['Adventure'].sum() + this_actor['Comedy'].sum() > 0:
        names_aq1.append(x)
        ROI_aq1.append(ROI_aq1_mean)

#This zips the above loops and puts them into a dataframe. The dataframe will be used for visualization.
    
zipped_name_ROI_2_aq1 = sorted(zip(names_aq1, ROI_aq1), reverse=True)
df1_aq1 = pd.DataFrame(zipped_name_ROI_2_aq1, columns=['Actor Names', 'Average ROI'])
df1_aq1.sort_values(by='Average ROI', ascending=False, inplace=True)
df1_aq1.head(20)
# Out:
#          Actor Names  Average ROI
# 145     J.K. Simmons     7.820853
# 31   Seth MacFarlane     6.591352
# 56    Patrick Wilson     6.060466
# 218   Benjamin Bratt     5.837510
# 100         Josh Gad     5.166315
# 7       Will Poulter     4.630124
# 81    Mahershala Ali     4.612230
# 171    Dylan O'Brien     4.473413
# 22       T.J. Miller     4.311556
# 106         Jon Hamm     4.290814
# 52       Paul Walker     4.218924
# 68    Michael Keaton     4.075456
# 212   Bradley Cooper     4.059000
# 128      Jason Segel     4.011721
# 173      Don Cheadle     3.970042
# 26     Stanley Tucci     3.915051
# 92        Kevin Hart     3.865468
# 37       Sam Claflin     3.808806
# 99   Josh Hutcherson     3.673106
# 138     James Corden     3.648372

# %% [markdown]
# <b>Plot the figures to show actors and their respective avergage ROI.</b>

# %%
#edit the .head() to view different amounts. typically we viewed the top 12
sns.barplot(data=df1_aq1.head(12), x='Actor Names', y="Average ROI")
plt.xticks(rotation=75)
plt.title('')
plt.show()

# %% [markdown]
# ## ACTRESSES
#
# ### This section outlines actress recommendations. We use a sequence of queries, and loops to narrow the actress that were a part of movies using a 24mil+ budget, and were casted in at least 3 movies since 2010.¶

# %%
## The following cell queries the actors dataframe with a $24Mill+ budget.

aq3 = ("""
SELECT person_name, movie, inf_adj_production_budget, ROI, Comedy, Action, Adventure
FROM actresses
WHERE inf_adj_production_budget >= 2.4e7
ORDER BY ROI
""")

actresses_aq3 = pysqldf(aq3)

# %%
actresses_aq3
# Out:
#            person_name              movie  inf_adj_production_budget  \
# 0          Haylie Duff         Foodfight!                   58169890
# 1          Hilary Duff         Foodfight!                   58169890
# 2         Eva Longoria         Foodfight!                   58169890
# 3      Mackenzie Davis   Freaks of Nature                   41180555
# 4     Beverly D'Angelo    Accidental Love                   32681495
# ...                ...                ...                        ...
# 1145      Vera Farmiga      The Conjuring                   25411137
# 1146      Lucy Boynton  Bohemian Rhapsody                   64767356
# 1147     Sophia Lillis                 It                   42087096
# 1148        Emma Stone         La La Land                   24586384
# 1149  Rosemarie DeWitt         La La Land                   24586384
#
#             ROI  Comedy  Action  Adventure
# 0     -0.998362       1       1          0
# 1     -0.998362       1       1          0
# 2     -0.998362       1       1          0
# 3     -0.997850       1       0          0
# 4     -0.994791       1       0          0
# ...         ...     ...     ...        ...
# 1145  14.900007       0       0          0
# 1146  15.272461       0       0          0
# 1147  18.927371       0       0          0
# 1148  20.317558       1       0          0
# 1149  20.317558       1       0          0
#
# [1150 rows x 7 columns]

# %%
#This loop sorts by number of movies, and selects the actresses that have been casted 3 or more

three_movies_aq3 = []
for x, y in zip(actresses_aq3['person_name'].value_counts(), actresses_aq3['person_name'].value_counts().index.tolist()):
    if x >= 3:
        three_movies_aq3.append(y)
    
three_movies_aq3
# Out:
# ['Jennifer Lawrence',
#  'Emily Blunt',
#  'Viola Davis',
#  'Amy Adams',
#  'Anne Hathaway',
#  'Rachel McAdams',
#  'Emma Stone',
#  'Cameron Diaz',
#  'Cate Blanchett',
#  'Scarlett Johansson',
#  'Julia Roberts',
#  'Chloë Grace Moretz',
#  'Vera Farmiga',
#  'Kristen Wiig',
#  'Mila Kunis',
#  'Anna Kendrick',
#  'Zoe Saldana',
#  'Jennifer Aniston',
#  'Amanda Seyfried',
#  'Helen Mirren',
#  'Michelle Monaghan',
#  'Jessica Chastain',
#  'Maya Rudolph',
#  'Angelina Jolie',
#  'Charlize Theron',
#  'Jennifer Garner',
#  'Anna Faris',
#  'Rose Byrne',
#  'Melissa McCarthy',
#  'Meryl Streep',
#  'Milla Jovovich',
#  'Kristen Bell',
#  'Hailee Steinfeld',
#  'Kate Winslet',
#  'Bryce Dallas Howard',
#  'Rooney Mara',
#  'Alicia Vikander',
#  'Rosamund Pike',
#  'Natalie Portman',
#  'Teresa Palmer',
#  'Reese Witherspoon',
#  'Dakota Johnson',
#  'Penélope Cruz',
#  'Katherine Heigl',
#  'Brie Larson',
#  'Rebecca Ferguson',
#  'Margot Robbie',
#  'Helena Bonham Carter',
#  'Tina Fey',
#  'Keira Knightley',
#  'Jennifer Connelly',
#  'Alice Braga',
#  'Gwyneth Paltrow',
#  'Maggie Grace',
#  'Elle Fanning',
#  'Shailene Woodley',
#  'Taraji P. Henson',
#  'Katherine Waterston',
#  'Rachel Weisz',
#  'Amy Poehler',
#  'Amber Heard',
#  'Jessica Alba',
#  'Michelle Williams',
#  'Tessa Thompson',
#  'Salma Hayek',
#  'Alexandra Daddario',
#  'Leslie Mann',
#  'Abbie Cornish',
#  'Emma Thompson',
#  'Selena Gomez',
#  'Regina Hall',
#  'Sigourney Weaver',
#  'Christina Applegate',
#  'Cobie Smulders',
#  'Abigail Breslin',
#  'Wendi McLendon-Covey',
#  'Rosario Dawson',
#  'Jennifer Jason Leigh',
#  'Michelle Rodriguez',
#  'Kathryn Hahn',
#  'Emily Mortimer',
#  'Ashley Judd',
#  'Marisa Tomei',
#  'Evangeline Lilly',
#  'Ellen Page',
#  'Drew Barrymore',
#  'Emma Watson',
#  'Eva Green',
#  'Kate McKinnon',
#  'Mia Wasikowska',
#  'Elizabeth Banks',
#  'Rihanna',
#  'Lily James',
#  'Winona Ryder',
#  'Gal Gadot',
#  'Rebecca Hall',
#  'Lily Collins',
#  'Saoirse Ronan',
#  'Amy Schumer',
#  'Rebel Wilson',
#  'Emily Watson',
#  'Jennifer Lopez',
#  'Julianne Hough',
#  'Kate Mara',
#  'Naomie Harris',
#  'Naomi Watts',
#  'Olivia Wilde',
#  'Blake Lively',
#  'Emily Browning',
#  'Kristen Stewart',
#  'Kate Bosworth',
#  'Noomi Rapace',
#  'Elisabeth Shue',
#  'Nicole Kidman',
#  'Zoë Kravitz',
#  'Felicity Jones',
#  'Amy Ryan',
#  'Eloise Mumford',
#  'Diane Kruger',
#  'Diane Lane',
#  'Keri Russell',
#  'Sarah Silverman',
#  'Olivia Munn',
#  'Sandra Bullock',
#  'Malin Akerman',
#  'Gemma Arterton',
#  'Britt Robertson',
#  'Megan Fox',
#  'Jodie Foster']

# %%
# This gets two lists, one is the names of actresses, the other is the respective ROIs. 
# This loop also sorts by genres Action, Adventure, Comedy.


names_aq3 = []
ROI_aq3 = []
for x in three_movies_aq3:
    ROI_aq3_mean = actresses_aq3[actresses_aq3['person_name'] == x]['ROI'].mean()
    this_actor = actresses_aq3[actresses_aq3['person_name'] == x]
    if this_actor['Action'].sum() + this_actor['Adventure'].sum() + this_actor['Comedy'].sum() > 0:
        names_aq3.append(x)
        ROI_aq3.append(ROI_aq3_mean)

#This zips the above loops and puts them into a dataframe. The dataframe will be used for visualization.
    
zipped_name_ROI_aq3 = sorted(zip(names_aq3, ROI_aq3), reverse=True)
df1_aq3 = pd.DataFrame(zipped_name_ROI_aq3, columns=['Actress Names', 'Average ROI'])
df1_aq3.sort_values(by='Average ROI', ascending=False, inplace=True)
df1_aq3
# Out:
#             Actress Names  Average ROI
# 16         Sandra Bullock     8.109692
# 53           Kristen Wiig     5.580418
# 104   Bryce Dallas Howard     4.739587
# 9        Taraji P. Henson     4.389355
# 55           Kristen Bell     4.289650
# ..                    ...          ...
# 67           Jodie Foster     0.383236
# 33           Noomi Rapace     0.344334
# 72   Jennifer Jason Leigh     0.344319
# 105       Britt Robertson     0.213798
# 64          Kate Bosworth     0.000888
#
# [124 rows x 2 columns]

# %%
sns.barplot(data=df1_aq3.head(12), x='Actress Names', y="Average ROI")
plt.xticks(rotation=75)
plt.title('')
plt.show()

# %% [markdown]
# The following cells queries the actresses that were movies that budgeted 45million or more

# %% [markdown]
# ## WRITERS
#
# ### This section outlines writer recommendations. We use a sequence of queries, and loops to narrow the writers that were a part of movies using a 24mil+ budget, and were casted in at least 3 movies since 2010.¶

# %%
## The following cell queries the writers dataframe with a $24Mill+ budget.

wq1 = ("""
SELECT person_name, movie, inf_adj_production_budget, ROI, Comedy, Action, Adventure
FROM writers
WHERE inf_adj_production_budget >= 2.4e7
ORDER BY ROI
""")

writers_wq1 = pysqldf(wq1)

# %%
#This loop sorts by number of movies, and selects the writers that have been casted 3 or more

three_movies_wq1 = []
for x, y in zip(writers_wq1['person_name'].value_counts(), writers_wq1['person_name'].value_counts().index.tolist()):
    if x >= 3:
        three_movies_wq1.append(y)
    
three_movies_wq1
# Out:
# ['Stan Lee',
#  'Jack Kirby',
#  'Nicholas Stoller',
#  'Stephen McFeely',
#  'Christopher Markus',
#  'Darren Lemke',
#  'Allan Loeb',
#  'Luc Besson',
#  'Richard Wenk',
#  'John Morris',
#  'Nicholas Sparks',
#  'Mark Bomback',
#  'Ken Daurio',
#  'John Gatins',
#  'Brian Lynch',
#  'Jonathan Aibel',
#  'Glenn Berger',
#  'John Francis Daley',
#  'Jonathan Goldstein',
#  'Rick Jaffa',
#  'Amanda Silver',
#  'Jared Stern',
#  'Cinco Paul',
#  'James Vanderbilt',
#  'Jeff Pinkner',
#  'John Logan',
#  'Jon Spaihts',
#  'Michael Green',
#  'Josh Singer',
#  'Joe Simon',
#  'Simon Kinberg',
#  'Jez Butterworth',
#  'Matt Manfredi',
#  'Robert Mark Kamen',
#  'Peter Baynham',
#  'Christopher McQuarrie',
#  'Peter Craig',
#  'Ehren Kruger',
#  'Michael Arndt',
#  'Skip Woods',
#  'Aline Brosh McKenna',
#  'Dan Fogelman',
#  'Suzanne Collins',
#  'Simon Beaufoy',
#  'Eric Heisserer',
#  'Evan Daugherty',
#  'Linda Woolverton',
#  'Stephen King',
#  'Akiva Goldsman',
#  'Chris McKenna',
#  'Dave Callaham',
#  'Philippa Boyens',
#  'Seth Grahame-Smith',
#  'Rhett Reese',
#  'Larry Lieber',
#  'Sean Anders',
#  'Fran Walsh',
#  'Evan Goldberg',
#  'Chris Morgan',
#  'Phil Hay',
#  'Paul Wernick',
#  'Jane Goldman',
#  'Damon Lindelof',
#  'Matt Sazama',
#  'Burk Sharpless',
#  'Jay Scherick',
#  'David Ronn',
#  'Ted Elliott',
#  'Erik Sommers',
#  'Bill Collage',
#  "Dan O'Bannon",
#  'Adam Cooper',
#  'William Davies',
#  'David Dobkin',
#  'Michael Finch',
#  'David S. Goyer',
#  'Robert Wade',
#  'Neal Purvis',
#  'Meg LeFauve',
#  'Max Borenstein',
#  'Timothy Dowling',
#  'Gary Scott Thompson',
#  'Cressida Cowell',
#  'Adam McKay',
#  'John Hamburg',
#  'Jason Fuchs',
#  'Steven Knight',
#  'Josh Appelbaum',
#  'André Nemec',
#  'Aaron Sorkin',
#  'Terry Rossio',
#  'Guillermo del Toro',
#  'J.R.R. Tolkien',
#  'Charles Perrault',
#  'Justin Theroux',
#  'Kurt Wimmer',
#  'John Ridley',
#  'Hossein Amini',
#  'William Nicholson',
#  'Katie Dippold',
#  'Phil Johnston',
#  'Erich Hoeber',
#  'Jon Hoeber',
#  'Jon Lucas',
#  'Scott Moore',
#  'Kelly Marcel',
#  'Pierre Boulle',
#  "Brendan O'Brien",
#  'Ethan Reiff',
#  'Cyrus Voris',
#  'John August',
#  'Derek Connolly',
#  'Bob Peterson',
#  'Ronald Shusett',
#  'Creighton Rothenberger',
#  'Travis Beacham',
#  'E.L. James',
#  'Robert Smigel',
#  'Steve Conrad',
#  'Steven Zaillian',
#  'Gary Whitta',
#  'Rob Lieber',
#  'David Leslie Johnson-McGoldrick',
#  'Michael Petroni',
#  'Robert L. Baird',
#  'Katrin Benedikt',
#  'David Koepp',
#  'Don Rhymer',
#  'David Lindsay-Abaire',
#  'Ryan Engle',
#  'Peter Morgan',
#  'Chris Terrio',
#  'Jerry Siegel',
#  'Jason Keller',
#  'Dan Gilroy',
#  'Mark Millar',
#  'Kenya Barris',
#  'Joshua Sternin',
#  'J.R. Ventimilia',
#  'T.S. Nowlin',
#  'Danny Strong',
#  'Adam Sztykiel',
#  'Erica Rivinoja',
#  'Roberto Orci']

# %%
# This gets two lists, one is the names of writers, the other is the respective ROIs. 
# This loop also sorts by genres Action, Adventure, Comedy.


names_wq1 = []
ROI_wq1 = []
for x in three_movies_wq1:
    ROI_wq1_mean = writers_wq1[writers_wq1['person_name'] == x]['ROI'].mean()
    this_actor = writers_wq1[writers_wq1['person_name'] == x]
    if this_actor['Action'].sum() + this_actor['Adventure'].sum() + this_actor['Comedy'].sum() > 0:
        names_wq1.append(x)
        ROI_wq1.append(ROI_wq1_mean)

#This zips the above loops and puts them into a dataframe. The dataframe will be used for visualization.
    
zipped_name_ROI_wq1 = sorted(zip(names_wq1, ROI_wq1), reverse=True)
df1_wq1 = pd.DataFrame(zipped_name_ROI_wq1, columns=['Writer Names', 'Average ROI'])
df1_wq1.sort_values(by='Average ROI', ascending=False, inplace=True)
df1_wq1
# Out:
#       Writer Names  Average ROI
# 119     Cinco Paul     8.864475
# 56      Ken Daurio     8.864475
# 57    Kelly Marcel     7.306154
# 12    Stephen King     6.444930
# 127    Brian Lynch     6.236830
# ..             ...          ...
# 54     Kurt Wimmer     0.732556
# 133     Allan Loeb     0.527783
# 88   Hossein Amini     0.486979
# 80    Jason Keller     0.216173
# 108   David Dobkin    -0.193349
#
# [139 rows x 2 columns]

# %%
sns.barplot(data=df1_wq1.head(12), x='Writer Names', y="Average ROI")
plt.xticks(rotation=75)
plt.title('')
plt.show()

# %% [markdown]
# ## Producers

# %% [markdown]
# ### This section outlines producer recommendations. We use a sequence of queries, and loops to narrow the actress that were a part of movies using a 24mil+ budget, and were casted in at least 3 movies since 2010.¶

# %%
## The following cell queries the producers dataframe with a $24Mill+ budget.

pq1 = ("""
SELECT person_name, movie, inf_adj_production_budget, ROI, Comedy, Action, Adventure
FROM producers
WHERE inf_adj_production_budget >= 2.4e7
ORDER BY ROI
""")

producers_pq1 = pysqldf(pq1)

# %%
#This loop sorts by number of movies, and selects the producers that have been casted 3 or more

three_movies_pq1 = []
for x, y in zip(producers_pq1['person_name'].value_counts(), producers_pq1['person_name'].value_counts().index.tolist()):
    if x >= 3:
        three_movies_pq1.append(y)
    
three_movies_pq1
# Out:
# ['Tim Bevan',
#  'Eric Fellner',
#  'Lorenzo di Bonaventura',
#  'Michael De Luca',
#  'Peter Chernin',
#  'Broderick Johnson',
#  'Neal H. Moritz',
#  'Andrew A. Kosove',
#  'Beau Flynn',
#  'Scott Stuber',
#  'Todd Black',
#  'Ryan Kavanaugh',
#  'Arnon Milchan',
#  'Graham King',
#  'Wyck Godfrey',
#  'Brian Grazer',
#  'Scott Rudin',
#  'Simon Kinberg',
#  'Nina Jacobson',
#  'Karen Rosenfelt',
#  'Mark Canton',
#  'Marc Platt',
#  'Marty Bowen',
#  'John Davis',
#  'Todd Garner',
#  'Dana Brunetti',
#  'Dede Gardner',
#  'Jenno Topping',
#  'Shawn Levy',
#  'Joe Roth',
#  'Jon Kilik',
#  'Jason Blumenthal',
#  'Anthony Katagas',
#  'Charles Roven',
#  'Judd Apatow',
#  'Basil Iwanyk',
#  'Kevin Feige',
#  'Chris Bender',
#  'Janet Healy',
#  'Bill Block',
#  'Christopher Meledandri',
#  'Patrick Crowley',
#  'Frank Marshall',
#  'Steve Starkey',
#  'Andrew Rona',
#  'Jon Jashni',
#  'David Hoberman',
#  'Randall Emmett',
#  'Megan Ellison',
#  'Nira Park',
#  'Todd Lieberman',
#  'Mark Johnson',
#  'Jennifer Gibgot',
#  'Stacey Sher',
#  'Jennifer Davisson',
#  'Leonardo DiCaprio',
#  'Brian Oliver',
#  'Sidney Kimmel',
#  'Adam McKay',
#  'Laurie MacDonald',
#  'Ian Bryce',
#  'Jack Giarraputo',
#  'Stephen Levinson',
#  'Donald De Line',
#  'Mark Gordon',
#  'Robert Chartoff',
#  'Dan Levine',
#  'Denise Di Novi',
#  'Michael Shamberg',
#  'David Heyman',
#  'Michael Barnathan',
#  'Donna Gigliotti',
#  'Michael Fottrell',
#  'Tim Headington',
#  'Jeremy Bolt',
#  'Will Packer',
#  'Avi Lerner',
#  'Emma Thomas',
#  'Peter Safran',
#  'Walter F. Parkes',
#  'Kathleen Kennedy',
#  'Jimmy Miller',
#  'Gary Lucchesi',
#  'René Besson',
#  'Adam Bohling',
#  'Steve Golin',
#  'Stuart Cornfeld',
#  'Jeremy Kleiner',
#  'Will Ferrell',
#  'Thomas Tull',
#  'Robert Kulzer',
#  'Julie Yorn',
#  'Jack Rapke',
#  'Don Carmody',
#  'Mary Parent',
#  'Mike Karz',
#  'Duncan Henderson',
#  'Rodney Rothman',
#  'Danny Lerner',
#  'Christi Dembrowski',
#  'Deborah Forte',
#  'Carolynne Cunningham',
#  'Virginie Besson-Silla',
#  'Mark Gill',
#  'Jerry Bruckheimer',
#  'Paul Brooks',
#  'Pamela Abdy',
#  'Paul Webster',
#  'Garrett Grant',
#  'Tripp Vinson',
#  'Marc Abraham',
#  'Evan Goldberg',
#  'Larry Franco',
#  'Gregory Goodman',
#  'Michael Tadross',
#  'Eric Newman',
#  'Kristie Macosko Krieger',
#  'Robert Simonds',
#  'Kevin McCormick',
#  'Christian Colson',
#  'Marc D. Evans',
#  'Matt Alvarez',
#  'Gregory Jacobs',
#  'Alison Owen',
#  'David Barron',
#  'Bruna Papandrea',
#  'Don Murphy',
#  'Tom DeSanto',
#  'Suzanne Todd',
#  'James Weaver',
#  'James Lassiter',
#  'Roger Birnbaum',
#  'Robert Lorenz',
#  'Bernie Goldmann',
#  'Jonathan Gordon',
#  'Gary Barber',
#  'Dan Lin',
#  'Tim Moore',
#  'Kevin King Templeton',
#  'Lucy Fisher',
#  'Michael Schaefer',
#  'William Chartoff',
#  'Steven Chasman',
#  'Michael Bay',
#  'Remington Chase',
#  'Dylan Clark',
#  'Bryan Burk',
#  'Grant Heslov',
#  'Tom Rosenberg',
#  'Robert Teitel',
#  'Chris Henchy',
#  'Ceán Chaffin',
#  'Thad Luckinbill',
#  'David Winkler',
#  'Jennifer Todd',
#  'Laurence Mark',
#  'Sam Mercer']

# %%
# This gets two lists, one is the names of producers, the other is the respective ROIs. 
# This loop also sorts by genres Action, Adventure, Comedy.


names_pq1 = []
ROI_pq1 = []
for x in three_movies_pq1:
    ROI_pq1_mean = producers_pq1[producers_pq1['person_name'] == x]['ROI'].mean()
    this_actor = producers_pq1[producers_pq1['person_name'] == x]
    if this_actor['Action'].sum() + this_actor['Adventure'].sum() + this_actor['Comedy'].sum() > 0:
        names_pq1.append(x)
        ROI_pq1.append(ROI_pq1_mean)

#This zips the above loops and puts them into a dataframe. The dataframe will be used for visualization.
    
zipped_name_ROI_pq1 = sorted(zip(names_pq1, ROI_pq1), reverse=True)
df1_pq1 = pd.DataFrame(zipped_name_ROI_pq1, columns=['Producer Names', 'Average ROI'])
df1_pq1.sort_values(by='Average ROI', ascending=False, inplace=True)
df1_pq1.head(20)
# Out:
#              Producer Names  Average ROI
# 94              Janet Healy     9.668003
# 129  Christopher Meledandri     7.276575
# 39             Peter Safran     5.624838
# 126           Dana Brunetti     5.475595
# 80          Jonathan Gordon     5.463420
# 16             Suzanne Todd     5.246161
# 23            Simon Kinberg     5.210564
# 114         Donna Gigliotti     4.740473
# 42              Paul Brooks     4.610706
# 52         Michael Fottrell     4.579467
# 56             Matt Alvarez     4.496952
# 46            Nina Jacobson     4.483051
# 63               Marc Platt     4.469281
# 8               Tom DeSanto     4.193699
# 116              Don Murphy     4.193699
# 75              Kevin Feige     4.149226
# 9            Todd Lieberman     3.875942
# 122          David Hoberman     3.875942
# 5     Virginie Besson-Silla     3.778434
# 150             Alison Owen     3.656538

# %%
sns.barplot(data=df1_pq1.head(12), x='Producer Names', y="Average ROI")
plt.xticks(rotation=75)
plt.title('')
plt.show()
